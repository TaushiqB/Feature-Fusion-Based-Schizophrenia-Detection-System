# %%
import numpy as np
import cv2
import os
import re
import tensorflow
from tensorflow.keras.preprocessing.image import load_img, img_to_array, ImageDataGenerator
from tensorflow.keras.applications.vgg16 import preprocess_input
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)

# Load dataset and preprocess
healthy_path_train = '/content/gdrive/My Drive/Colab Notebooks/dataset_175/train/healthy'
schizophrenia_path_train = '/content/gdrive/My Drive/Colab Notebooks/dataset_175/train/schizophrenia'
healthy_path_test = '/content/gdrive/My Drive/Colab Notebooks/dataset_175/test/healthy'
schizophrenia_path_test = '/content/gdrive/My Drive/Colab Notebooks/dataset_175/test/schizophrenia'

def load_dataset(healthy_path_train, schizophrenia_path_train, healthy_path_test, schizophrenia_path_test):
    images_train = []
    images_test = []
    labels_train = []
    labels_test = []
    for img in os.listdir(healthy_path_train):
        img_path = os.path.join(healthy_path_train, img)
        image = load_img(img_path, target_size=(224, 224))
        image = img_to_array(image)
        images_train.append(image)
        labels_train.append(0)
    for img in os.listdir(schizophrenia_path_train):
        img_path = os.path.join(schizophrenia_path_train, img)
        image = load_img(img_path, target_size=(224, 224))
        image = img_to_array(image)
        images_train.append(image)
        labels_train.append(1)
    for img in os.listdir(healthy_path_test):
        img_path = os.path.join(healthy_path_test, img)
        image = load_img(img_path, target_size=(224, 224))
        image = img_to_array(image)
        images_test.append(image)
        labels_test.append(0)
    for img in os.listdir(schizophrenia_path_test):
        img_path = os.path.join(schizophrenia_path_test, img)
        image = load_img(img_path, target_size=(224, 224))
        image = img_to_array(image)
        images_test.append(image)
        labels_test.append(1)
    return np.array(images_train), np.array(images_test), np.array(labels_train), np.array(labels_test)

X_train_dl, X_test_dl, y_train_dl, y_test_dl = load_dataset(healthy_path_train, schizophrenia_path_train, healthy_path_test, schizophrenia_path_test)
print("Dataset loaded")

#print(X_train_dl, X_test_dl, y_train_dl, y_test_dl)
print(len(X_train_dl),len(X_train_dl[0]), X_train_dl[0].shape, len(X_test_dl), len(y_train_dl), len(y_test_dl))

from google.colab.patches import cv2_imshow
cv2_imshow(X_train_dl[5])
cv2_imshow(X_test_dl[5])
# Out:
# Mounted at /content/gdrive
# Dataset loaded
# 175 224 (224, 224, 3) 75 175 75
# <PIL.Image.Image image mode=RGB size=224x224>
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
import os
import time
import numpy as np
import tensorflow
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Flatten, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.models import Model, Sequential
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, roc_curve, auc, roc_auc_score
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt


X_train_dl_split, X_test_dl_split, y_train_dl_split, y_test_dl_split  = X_train_dl, X_test_dl, to_categorical(y_train_dl, num_classes=2), to_categorical(y_test_dl, num_classes=2)
print(len(X_train_dl_split),len(X_train_dl_split[0]), X_train_dl_split[0].shape, len(X_test_dl_split), len(y_train_dl_split),  len(y_test_dl_split))

# Build and compile the model
base_model = tensorflow.keras.applications.InceptionV3(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
base_model.summary()
base_model.trainable = False

# Freeze all layers except some convolutional layers
for layer in base_model.layers[-50:]:
    layer.trainable = True
for layer in base_model.layers:
    print("{0}:\t{1}".format(layer.trainable, layer.name))

model = Sequential([
    layers.Rescaling(1./224),
    base_model,
    layers.Flatten(),
    layers.Dense(1024, activation = 'relu'),
    layers.Dropout(0.5),
    layers.Dense(2048, activation = 'relu'),
    layers.Dropout(0.5),
    layers.Dense(4096, activation = 'relu'),
    layers.Dense(2, activation = 'softmax')
])

model.compile(optimizer=tensorflow.keras.optimizers.Adam(learning_rate=0.00001), loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# 175 224 (224, 224, 3) 75 175 75
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_11 (InputLayer)       [(None, 224, 224, 3)]        0         []
#
#  conv2d_940 (Conv2D)         (None, 111, 111, 32)         864       ['input_11[0][0]']
#
#  batch_normalization_940 (B  (None, 111, 111, 32)         96        ['conv2d_940[0][0]']
#  atchNormalization)
#
#  activation_940 (Activation  (None, 111, 111, 32)         0         ['batch_normalization_940[0][0
#  )                                                                  ]']
#
#  conv2d_941 (Conv2D)         (None, 109, 109, 32)         9216      ['activation_940[0][0]']
#
#  batch_normalization_941 (B  (None, 109, 109, 32)         96        ['conv2d_941[0][0]']
#  atchNormalization)
#
#  activation_941 (Activation  (None, 109, 109, 32)         0         ['batch_normalization_941[0][0
#  )                                                                  ]']
#
#  conv2d_942 (Conv2D)         (None, 109, 109, 64)         18432     ['activation_941[0][0]']
#
#  batch_normalization_942 (B  (None, 109, 109, 64)         192       ['conv2d_942[0][0]']
#  atchNormalization)
#
#  activation_942 (Activation  (None, 109, 109, 64)         0         ['batch_normalization_942[0][0
#  )                                                                  ]']
#
#  max_pooling2d_40 (MaxPooli  (None, 54, 54, 64)           0         ['activation_942[0][0]']
#  ng2D)
#
#  conv2d_943 (Conv2D)         (None, 54, 54, 80)           5120      ['max_pooling2d_40[0][0]']
#
#  batch_normalization_943 (B  (None, 54, 54, 80)           240       ['conv2d_943[0][0]']
#  atchNormalization)
#
#  activation_943 (Activation  (None, 54, 54, 80)           0         ['batch_normalization_943[0][0
#  )                                                                  ]']
#
#  conv2d_944 (Conv2D)         (None, 52, 52, 192)          138240    ['activation_943[0][0]']
#
#  batch_normalization_944 (B  (None, 52, 52, 192)          576       ['conv2d_944[0][0]']
#  atchNormalization)
#
#  activation_944 (Activation  (None, 52, 52, 192)          0         ['batch_normalization_944[0][0
#  )                                                                  ]']
#
#  max_pooling2d_41 (MaxPooli  (None, 25, 25, 192)          0         ['activation_944[0][0]']
#  ng2D)
#
#  conv2d_948 (Conv2D)         (None, 25, 25, 64)           12288     ['max_pooling2d_41[0][0]']
#
#  batch_normalization_948 (B  (None, 25, 25, 64)           192       ['conv2d_948[0][0]']
#  atchNormalization)
#
#  activation_948 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_948[0][0
#  )                                                                  ]']
#
#  conv2d_946 (Conv2D)         (None, 25, 25, 48)           9216      ['max_pooling2d_41[0][0]']
#
#  conv2d_949 (Conv2D)         (None, 25, 25, 96)           55296     ['activation_948[0][0]']
#
#  batch_normalization_946 (B  (None, 25, 25, 48)           144       ['conv2d_946[0][0]']
#  atchNormalization)
#
#  batch_normalization_949 (B  (None, 25, 25, 96)           288       ['conv2d_949[0][0]']
#  atchNormalization)
#
#  activation_946 (Activation  (None, 25, 25, 48)           0         ['batch_normalization_946[0][0
#  )                                                                  ]']
#
#  activation_949 (Activation  (None, 25, 25, 96)           0         ['batch_normalization_949[0][0
#  )                                                                  ]']
#
#  average_pooling2d_90 (Aver  (None, 25, 25, 192)          0         ['max_pooling2d_41[0][0]']
#  agePooling2D)
#
#  conv2d_945 (Conv2D)         (None, 25, 25, 64)           12288     ['max_pooling2d_41[0][0]']
#
#  conv2d_947 (Conv2D)         (None, 25, 25, 64)           76800     ['activation_946[0][0]']
#
#  conv2d_950 (Conv2D)         (None, 25, 25, 96)           82944     ['activation_949[0][0]']
#
#  conv2d_951 (Conv2D)         (None, 25, 25, 32)           6144      ['average_pooling2d_90[0][0]']
#
#  batch_normalization_945 (B  (None, 25, 25, 64)           192       ['conv2d_945[0][0]']
#  atchNormalization)
#
#  batch_normalization_947 (B  (None, 25, 25, 64)           192       ['conv2d_947[0][0]']
#  atchNormalization)
#
#  batch_normalization_950 (B  (None, 25, 25, 96)           288       ['conv2d_950[0][0]']
#  atchNormalization)
#
#  batch_normalization_951 (B  (None, 25, 25, 32)           96        ['conv2d_951[0][0]']
#  atchNormalization)
#
#  activation_945 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_945[0][0
#  )                                                                  ]']
#
#  activation_947 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_947[0][0
#  )                                                                  ]']
#
#  activation_950 (Activation  (None, 25, 25, 96)           0         ['batch_normalization_950[0][0
#  )                                                                  ]']
#
#  activation_951 (Activation  (None, 25, 25, 32)           0         ['batch_normalization_951[0][0
#  )                                                                  ]']
#
#  mixed0 (Concatenate)        (None, 25, 25, 256)          0         ['activation_945[0][0]',
#                                                                      'activation_947[0][0]',
#                                                                      'activation_950[0][0]',
#                                                                      'activation_951[0][0]']
#
#  conv2d_955 (Conv2D)         (None, 25, 25, 64)           16384     ['mixed0[0][0]']
#
#  batch_normalization_955 (B  (None, 25, 25, 64)           192       ['conv2d_955[0][0]']
#  atchNormalization)
#
#  activation_955 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_955[0][0
#  )                                                                  ]']
#
#  conv2d_953 (Conv2D)         (None, 25, 25, 48)           12288     ['mixed0[0][0]']
#
#  conv2d_956 (Conv2D)         (None, 25, 25, 96)           55296     ['activation_955[0][0]']
#
#  batch_normalization_953 (B  (None, 25, 25, 48)           144       ['conv2d_953[0][0]']
#  atchNormalization)
#
#  batch_normalization_956 (B  (None, 25, 25, 96)           288       ['conv2d_956[0][0]']
#  atchNormalization)
#
#  activation_953 (Activation  (None, 25, 25, 48)           0         ['batch_normalization_953[0][0
#  )                                                                  ]']
#
#  activation_956 (Activation  (None, 25, 25, 96)           0         ['batch_normalization_956[0][0
#  )                                                                  ]']
#
#  average_pooling2d_91 (Aver  (None, 25, 25, 256)          0         ['mixed0[0][0]']
#  agePooling2D)
#
#  conv2d_952 (Conv2D)         (None, 25, 25, 64)           16384     ['mixed0[0][0]']
#
#  conv2d_954 (Conv2D)         (None, 25, 25, 64)           76800     ['activation_953[0][0]']
#
#  conv2d_957 (Conv2D)         (None, 25, 25, 96)           82944     ['activation_956[0][0]']
#
#  conv2d_958 (Conv2D)         (None, 25, 25, 64)           16384     ['average_pooling2d_91[0][0]']
#
#  batch_normalization_952 (B  (None, 25, 25, 64)           192       ['conv2d_952[0][0]']
#  atchNormalization)
#
#  batch_normalization_954 (B  (None, 25, 25, 64)           192       ['conv2d_954[0][0]']
#  atchNormalization)
#
#  batch_normalization_957 (B  (None, 25, 25, 96)           288       ['conv2d_957[0][0]']
#  atchNormalization)
#
#  batch_normalization_958 (B  (None, 25, 25, 64)           192       ['conv2d_958[0][0]']
#  atchNormalization)
#
#  activation_952 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_952[0][0
#  )                                                                  ]']
#
#  activation_954 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_954[0][0
#  )                                                                  ]']
#
#  activation_957 (Activation  (None, 25, 25, 96)           0         ['batch_normalization_957[0][0
#  )                                                                  ]']
#
#  activation_958 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_958[0][0
#  )                                                                  ]']
#
#  mixed1 (Concatenate)        (None, 25, 25, 288)          0         ['activation_952[0][0]',
#                                                                      'activation_954[0][0]',
#                                                                      'activation_957[0][0]',
#                                                                      'activation_958[0][0]']
#
#  conv2d_962 (Conv2D)         (None, 25, 25, 64)           18432     ['mixed1[0][0]']
#
#  batch_normalization_962 (B  (None, 25, 25, 64)           192       ['conv2d_962[0][0]']
#  atchNormalization)
#
#  activation_962 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_962[0][0
#  )                                                                  ]']
#
#  conv2d_960 (Conv2D)         (None, 25, 25, 48)           13824     ['mixed1[0][0]']
#
#  conv2d_963 (Conv2D)         (None, 25, 25, 96)           55296     ['activation_962[0][0]']
#
#  batch_normalization_960 (B  (None, 25, 25, 48)           144       ['conv2d_960[0][0]']
#  atchNormalization)
#
#  batch_normalization_963 (B  (None, 25, 25, 96)           288       ['conv2d_963[0][0]']
#  atchNormalization)
#
#  activation_960 (Activation  (None, 25, 25, 48)           0         ['batch_normalization_960[0][0
#  )                                                                  ]']
#
#  activation_963 (Activation  (None, 25, 25, 96)           0         ['batch_normalization_963[0][0
#  )                                                                  ]']
#
#  average_pooling2d_92 (Aver  (None, 25, 25, 288)          0         ['mixed1[0][0]']
#  agePooling2D)
#
#  conv2d_959 (Conv2D)         (None, 25, 25, 64)           18432     ['mixed1[0][0]']
#
#  conv2d_961 (Conv2D)         (None, 25, 25, 64)           76800     ['activation_960[0][0]']
#
#  conv2d_964 (Conv2D)         (None, 25, 25, 96)           82944     ['activation_963[0][0]']
#
#  conv2d_965 (Conv2D)         (None, 25, 25, 64)           18432     ['average_pooling2d_92[0][0]']
#
#  batch_normalization_959 (B  (None, 25, 25, 64)           192       ['conv2d_959[0][0]']
#  atchNormalization)
#
#  batch_normalization_961 (B  (None, 25, 25, 64)           192       ['conv2d_961[0][0]']
#  atchNormalization)
#
#  batch_normalization_964 (B  (None, 25, 25, 96)           288       ['conv2d_964[0][0]']
#  atchNormalization)
#
#  batch_normalization_965 (B  (None, 25, 25, 64)           192       ['conv2d_965[0][0]']
#  atchNormalization)
#
#  activation_959 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_959[0][0
#  )                                                                  ]']
#
#  activation_961 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_961[0][0
#  )                                                                  ]']
#
#  activation_964 (Activation  (None, 25, 25, 96)           0         ['batch_normalization_964[0][0
#  )                                                                  ]']
#
#  activation_965 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_965[0][0
#  )                                                                  ]']
#
#  mixed2 (Concatenate)        (None, 25, 25, 288)          0         ['activation_959[0][0]',
#                                                                      'activation_961[0][0]',
#                                                                      'activation_964[0][0]',
#                                                                      'activation_965[0][0]']
#
#  conv2d_967 (Conv2D)         (None, 25, 25, 64)           18432     ['mixed2[0][0]']
#
#  batch_normalization_967 (B  (None, 25, 25, 64)           192       ['conv2d_967[0][0]']
#  atchNormalization)
#
#  activation_967 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_967[0][0
#  )                                                                  ]']
#
#  conv2d_968 (Conv2D)         (None, 25, 25, 96)           55296     ['activation_967[0][0]']
#
#  batch_normalization_968 (B  (None, 25, 25, 96)           288       ['conv2d_968[0][0]']
#  atchNormalization)
#
#  activation_968 (Activation  (None, 25, 25, 96)           0         ['batch_normalization_968[0][0
#  )                                                                  ]']
#
#  conv2d_966 (Conv2D)         (None, 12, 12, 384)          995328    ['mixed2[0][0]']
#
#  conv2d_969 (Conv2D)         (None, 12, 12, 96)           82944     ['activation_968[0][0]']
#
#  batch_normalization_966 (B  (None, 12, 12, 384)          1152      ['conv2d_966[0][0]']
#  atchNormalization)
#
#  batch_normalization_969 (B  (None, 12, 12, 96)           288       ['conv2d_969[0][0]']
#  atchNormalization)
#
#  activation_966 (Activation  (None, 12, 12, 384)          0         ['batch_normalization_966[0][0
#  )                                                                  ]']
#
#  activation_969 (Activation  (None, 12, 12, 96)           0         ['batch_normalization_969[0][0
#  )                                                                  ]']
#
#  max_pooling2d_42 (MaxPooli  (None, 12, 12, 288)          0         ['mixed2[0][0]']
#  ng2D)
#
#  mixed3 (Concatenate)        (None, 12, 12, 768)          0         ['activation_966[0][0]',
#                                                                      'activation_969[0][0]',
#                                                                      'max_pooling2d_42[0][0]']
#
#  conv2d_974 (Conv2D)         (None, 12, 12, 128)          98304     ['mixed3[0][0]']
#
#  batch_normalization_974 (B  (None, 12, 12, 128)          384       ['conv2d_974[0][0]']
#  atchNormalization)
#
#  activation_974 (Activation  (None, 12, 12, 128)          0         ['batch_normalization_974[0][0
#  )                                                                  ]']
#
#  conv2d_975 (Conv2D)         (None, 12, 12, 128)          114688    ['activation_974[0][0]']
#
#  batch_normalization_975 (B  (None, 12, 12, 128)          384       ['conv2d_975[0][0]']
#  atchNormalization)
#
#  activation_975 (Activation  (None, 12, 12, 128)          0         ['batch_normalization_975[0][0
#  )                                                                  ]']
#
#  conv2d_971 (Conv2D)         (None, 12, 12, 128)          98304     ['mixed3[0][0]']
#
#  conv2d_976 (Conv2D)         (None, 12, 12, 128)          114688    ['activation_975[0][0]']
#
#  batch_normalization_971 (B  (None, 12, 12, 128)          384       ['conv2d_971[0][0]']
#  atchNormalization)
#
#  batch_normalization_976 (B  (None, 12, 12, 128)          384       ['conv2d_976[0][0]']
#  atchNormalization)
#
#  activation_971 (Activation  (None, 12, 12, 128)          0         ['batch_normalization_971[0][0
#  )                                                                  ]']
#
#  activation_976 (Activation  (None, 12, 12, 128)          0         ['batch_normalization_976[0][0
#  )                                                                  ]']
#
#  conv2d_972 (Conv2D)         (None, 12, 12, 128)          114688    ['activation_971[0][0]']
#
#  conv2d_977 (Conv2D)         (None, 12, 12, 128)          114688    ['activation_976[0][0]']
#
#  batch_normalization_972 (B  (None, 12, 12, 128)          384       ['conv2d_972[0][0]']
#  atchNormalization)
#
#  batch_normalization_977 (B  (None, 12, 12, 128)          384       ['conv2d_977[0][0]']
#  atchNormalization)
#
#  activation_972 (Activation  (None, 12, 12, 128)          0         ['batch_normalization_972[0][0
#  )                                                                  ]']
#
#  activation_977 (Activation  (None, 12, 12, 128)          0         ['batch_normalization_977[0][0
#  )                                                                  ]']
#
#  average_pooling2d_93 (Aver  (None, 12, 12, 768)          0         ['mixed3[0][0]']
#  agePooling2D)
#
#  conv2d_970 (Conv2D)         (None, 12, 12, 192)          147456    ['mixed3[0][0]']
#
#  conv2d_973 (Conv2D)         (None, 12, 12, 192)          172032    ['activation_972[0][0]']
#
#  conv2d_978 (Conv2D)         (None, 12, 12, 192)          172032    ['activation_977[0][0]']
#
#  conv2d_979 (Conv2D)         (None, 12, 12, 192)          147456    ['average_pooling2d_93[0][0]']
#
#  batch_normalization_970 (B  (None, 12, 12, 192)          576       ['conv2d_970[0][0]']
#  atchNormalization)
#
#  batch_normalization_973 (B  (None, 12, 12, 192)          576       ['conv2d_973[0][0]']
#  atchNormalization)
#
#  batch_normalization_978 (B  (None, 12, 12, 192)          576       ['conv2d_978[0][0]']
#  atchNormalization)
#
#  batch_normalization_979 (B  (None, 12, 12, 192)          576       ['conv2d_979[0][0]']
#  atchNormalization)
#
#  activation_970 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_970[0][0
#  )                                                                  ]']
#
#  activation_973 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_973[0][0
#  )                                                                  ]']
#
#  activation_978 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_978[0][0
#  )                                                                  ]']
#
#  activation_979 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_979[0][0
#  )                                                                  ]']
#
#  mixed4 (Concatenate)        (None, 12, 12, 768)          0         ['activation_970[0][0]',
#                                                                      'activation_973[0][0]',
#                                                                      'activation_978[0][0]',
#                                                                      'activation_979[0][0]']
#
#  conv2d_984 (Conv2D)         (None, 12, 12, 160)          122880    ['mixed4[0][0]']
#
#  batch_normalization_984 (B  (None, 12, 12, 160)          480       ['conv2d_984[0][0]']
#  atchNormalization)
#
#  activation_984 (Activation  (None, 12, 12, 160)          0         ['batch_normalization_984[0][0
#  )                                                                  ]']
#
#  conv2d_985 (Conv2D)         (None, 12, 12, 160)          179200    ['activation_984[0][0]']
#
#  batch_normalization_985 (B  (None, 12, 12, 160)          480       ['conv2d_985[0][0]']
#  atchNormalization)
#
#  activation_985 (Activation  (None, 12, 12, 160)          0         ['batch_normalization_985[0][0
#  )                                                                  ]']
#
#  conv2d_981 (Conv2D)         (None, 12, 12, 160)          122880    ['mixed4[0][0]']
#
#  conv2d_986 (Conv2D)         (None, 12, 12, 160)          179200    ['activation_985[0][0]']
#
#  batch_normalization_981 (B  (None, 12, 12, 160)          480       ['conv2d_981[0][0]']
#  atchNormalization)
#
#  batch_normalization_986 (B  (None, 12, 12, 160)          480       ['conv2d_986[0][0]']
#  atchNormalization)
#
#  activation_981 (Activation  (None, 12, 12, 160)          0         ['batch_normalization_981[0][0
#  )                                                                  ]']
#
#  activation_986 (Activation  (None, 12, 12, 160)          0         ['batch_normalization_986[0][0
#  )                                                                  ]']
#
#  conv2d_982 (Conv2D)         (None, 12, 12, 160)          179200    ['activation_981[0][0]']
#
#  conv2d_987 (Conv2D)         (None, 12, 12, 160)          179200    ['activation_986[0][0]']
#
#  batch_normalization_982 (B  (None, 12, 12, 160)          480       ['conv2d_982[0][0]']
#  atchNormalization)
#
#  batch_normalization_987 (B  (None, 12, 12, 160)          480       ['conv2d_987[0][0]']
#  atchNormalization)
#
#  activation_982 (Activation  (None, 12, 12, 160)          0         ['batch_normalization_982[0][0
#  )                                                                  ]']
#
#  activation_987 (Activation  (None, 12, 12, 160)          0         ['batch_normalization_987[0][0
#  )                                                                  ]']
#
#  average_pooling2d_94 (Aver  (None, 12, 12, 768)          0         ['mixed4[0][0]']
#  agePooling2D)
#
#  conv2d_980 (Conv2D)         (None, 12, 12, 192)          147456    ['mixed4[0][0]']
#
#  conv2d_983 (Conv2D)         (None, 12, 12, 192)          215040    ['activation_982[0][0]']
#
#  conv2d_988 (Conv2D)         (None, 12, 12, 192)          215040    ['activation_987[0][0]']
#
#  conv2d_989 (Conv2D)         (None, 12, 12, 192)          147456    ['average_pooling2d_94[0][0]']
#
#  batch_normalization_980 (B  (None, 12, 12, 192)          576       ['conv2d_980[0][0]']
#  atchNormalization)
#
#  batch_normalization_983 (B  (None, 12, 12, 192)          576       ['conv2d_983[0][0]']
#  atchNormalization)
#
#  batch_normalization_988 (B  (None, 12, 12, 192)          576       ['conv2d_988[0][0]']
#  atchNormalization)
#
#  batch_normalization_989 (B  (None, 12, 12, 192)          576       ['conv2d_989[0][0]']
#  atchNormalization)
#
#  activation_980 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_980[0][0
#  )                                                                  ]']
#
#  activation_983 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_983[0][0
#  )                                                                  ]']
#
#  activation_988 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_988[0][0
#  )                                                                  ]']
#
#  activation_989 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_989[0][0
#  )                                                                  ]']
#
#  mixed5 (Concatenate)        (None, 12, 12, 768)          0         ['activation_980[0][0]',
#                                                                      'activation_983[0][0]',
#                                                                      'activation_988[0][0]',
#                                                                      'activation_989[0][0]']
#
#  conv2d_994 (Conv2D)         (None, 12, 12, 160)          122880    ['mixed5[0][0]']
#
#  batch_normalization_994 (B  (None, 12, 12, 160)          480       ['conv2d_994[0][0]']
#  atchNormalization)
#
#  activation_994 (Activation  (None, 12, 12, 160)          0         ['batch_normalization_994[0][0
#  )                                                                  ]']
#
#  conv2d_995 (Conv2D)         (None, 12, 12, 160)          179200    ['activation_994[0][0]']
#
#  batch_normalization_995 (B  (None, 12, 12, 160)          480       ['conv2d_995[0][0]']
#  atchNormalization)
#
#  activation_995 (Activation  (None, 12, 12, 160)          0         ['batch_normalization_995[0][0
#  )                                                                  ]']
#
#  conv2d_991 (Conv2D)         (None, 12, 12, 160)          122880    ['mixed5[0][0]']
#
#  conv2d_996 (Conv2D)         (None, 12, 12, 160)          179200    ['activation_995[0][0]']
#
#  batch_normalization_991 (B  (None, 12, 12, 160)          480       ['conv2d_991[0][0]']
#  atchNormalization)
#
#  batch_normalization_996 (B  (None, 12, 12, 160)          480       ['conv2d_996[0][0]']
#  atchNormalization)
#
# ...
#  batch_normalization_1029 (  (None, 5, 5, 448)            1344      ['conv2d_1029[0][0]']
#  BatchNormalization)
#
#  activation_1029 (Activatio  (None, 5, 5, 448)            0         ['batch_normalization_1029[0][
#  n)                                                                 0]']
#
#  conv2d_1026 (Conv2D)        (None, 5, 5, 384)            786432    ['mixed9[0][0]']
#
#  conv2d_1030 (Conv2D)        (None, 5, 5, 384)            1548288   ['activation_1029[0][0]']
#
#  batch_normalization_1026 (  (None, 5, 5, 384)            1152      ['conv2d_1026[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1030 (  (None, 5, 5, 384)            1152      ['conv2d_1030[0][0]']
#  BatchNormalization)
#
#  activation_1026 (Activatio  (None, 5, 5, 384)            0         ['batch_normalization_1026[0][
#  n)                                                                 0]']
#
#  activation_1030 (Activatio  (None, 5, 5, 384)            0         ['batch_normalization_1030[0][
#  n)                                                                 0]']
#
#  conv2d_1027 (Conv2D)        (None, 5, 5, 384)            442368    ['activation_1026[0][0]']
#
#  conv2d_1028 (Conv2D)        (None, 5, 5, 384)            442368    ['activation_1026[0][0]']
#
#  conv2d_1031 (Conv2D)        (None, 5, 5, 384)            442368    ['activation_1030[0][0]']
#
#  conv2d_1032 (Conv2D)        (None, 5, 5, 384)            442368    ['activation_1030[0][0]']
#
#  average_pooling2d_98 (Aver  (None, 5, 5, 2048)           0         ['mixed9[0][0]']
#  agePooling2D)
#
#  conv2d_1025 (Conv2D)        (None, 5, 5, 320)            655360    ['mixed9[0][0]']
#
#  batch_normalization_1027 (  (None, 5, 5, 384)            1152      ['conv2d_1027[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1028 (  (None, 5, 5, 384)            1152      ['conv2d_1028[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1031 (  (None, 5, 5, 384)            1152      ['conv2d_1031[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1032 (  (None, 5, 5, 384)            1152      ['conv2d_1032[0][0]']
#  BatchNormalization)
#
#  conv2d_1033 (Conv2D)        (None, 5, 5, 192)            393216    ['average_pooling2d_98[0][0]']
#
#  batch_normalization_1025 (  (None, 5, 5, 320)            960       ['conv2d_1025[0][0]']
#  BatchNormalization)
#
#  activation_1027 (Activatio  (None, 5, 5, 384)            0         ['batch_normalization_1027[0][
#  n)                                                                 0]']
#
#  activation_1028 (Activatio  (None, 5, 5, 384)            0         ['batch_normalization_1028[0][
#  n)                                                                 0]']
#
#  activation_1031 (Activatio  (None, 5, 5, 384)            0         ['batch_normalization_1031[0][
#  n)                                                                 0]']
#
#  activation_1032 (Activatio  (None, 5, 5, 384)            0         ['batch_normalization_1032[0][
#  n)                                                                 0]']
#
#  batch_normalization_1033 (  (None, 5, 5, 192)            576       ['conv2d_1033[0][0]']
#  BatchNormalization)
#
#  activation_1025 (Activatio  (None, 5, 5, 320)            0         ['batch_normalization_1025[0][
#  n)                                                                 0]']
#
#  mixed9_1 (Concatenate)      (None, 5, 5, 768)            0         ['activation_1027[0][0]',
#                                                                      'activation_1028[0][0]']
#
#  concatenate_21 (Concatenat  (None, 5, 5, 768)            0         ['activation_1031[0][0]',
#  e)                                                                  'activation_1032[0][0]']
#
#  activation_1033 (Activatio  (None, 5, 5, 192)            0         ['batch_normalization_1033[0][
#  n)                                                                 0]']
#
#  mixed10 (Concatenate)       (None, 5, 5, 2048)           0         ['activation_1025[0][0]',
#                                                                      'mixed9_1[0][0]',
#                                                                      'concatenate_21[0][0]',
#                                                                      'activation_1033[0][0]']
#
# ==================================================================================================
# Total params: 21802784 (83.17 MB)
# Trainable params: 21768352 (83.04 MB)
# Non-trainable params: 34432 (134.50 KB)
# __________________________________________________________________________________________________
# False:	input_11
# False:	conv2d_940
# False:	batch_normalization_940
# False:	activation_940
# False:	conv2d_941
# False:	batch_normalization_941
# False:	activation_941
# False:	conv2d_942
# False:	batch_normalization_942
# False:	activation_942
# False:	max_pooling2d_40
# False:	conv2d_943
# False:	batch_normalization_943
# False:	activation_943
# False:	conv2d_944
# False:	batch_normalization_944
# False:	activation_944
# False:	max_pooling2d_41
# False:	conv2d_948
# False:	batch_normalization_948
# False:	activation_948
# False:	conv2d_946
# False:	conv2d_949
# False:	batch_normalization_946
# False:	batch_normalization_949
# False:	activation_946
# False:	activation_949
# False:	average_pooling2d_90
# False:	conv2d_945
# False:	conv2d_947
# False:	conv2d_950
# False:	conv2d_951
# False:	batch_normalization_945
# False:	batch_normalization_947
# False:	batch_normalization_950
# False:	batch_normalization_951
# False:	activation_945
# False:	activation_947
# False:	activation_950
# False:	activation_951
# False:	mixed0
# False:	conv2d_955
# False:	batch_normalization_955
# False:	activation_955
# False:	conv2d_953
# False:	conv2d_956
# False:	batch_normalization_953
# False:	batch_normalization_956
# False:	activation_953
# False:	activation_956
# False:	average_pooling2d_91
# False:	conv2d_952
# False:	conv2d_954
# False:	conv2d_957
# False:	conv2d_958
# False:	batch_normalization_952
# False:	batch_normalization_954
# False:	batch_normalization_957
# False:	batch_normalization_958
# False:	activation_952
# False:	activation_954
# False:	activation_957
# False:	activation_958
# False:	mixed1
# False:	conv2d_962
# False:	batch_normalization_962
# False:	activation_962
# False:	conv2d_960
# False:	conv2d_963
# False:	batch_normalization_960
# False:	batch_normalization_963
# False:	activation_960
# False:	activation_963
# False:	average_pooling2d_92
# False:	conv2d_959
# False:	conv2d_961
# False:	conv2d_964
# False:	conv2d_965
# False:	batch_normalization_959
# False:	batch_normalization_961
# False:	batch_normalization_964
# False:	batch_normalization_965
# False:	activation_959
# False:	activation_961
# False:	activation_964
# False:	activation_965
# False:	mixed2
# False:	conv2d_967
# False:	batch_normalization_967
# False:	activation_967
# False:	conv2d_968
# False:	batch_normalization_968
# False:	activation_968
# False:	conv2d_966
# False:	conv2d_969
# False:	batch_normalization_966
# False:	batch_normalization_969
# False:	activation_966
# False:	activation_969
# False:	max_pooling2d_42
# False:	mixed3
# False:	conv2d_974
# False:	batch_normalization_974
# False:	activation_974
# False:	conv2d_975
# False:	batch_normalization_975
# False:	activation_975
# False:	conv2d_971
# False:	conv2d_976
# False:	batch_normalization_971
# False:	batch_normalization_976
# False:	activation_971
# False:	activation_976
# False:	conv2d_972
# False:	conv2d_977
# False:	batch_normalization_972
# False:	batch_normalization_977
# False:	activation_972
# False:	activation_977
# False:	average_pooling2d_93
# False:	conv2d_970
# False:	conv2d_973
# False:	conv2d_978
# False:	conv2d_979
# False:	batch_normalization_970
# False:	batch_normalization_973
# False:	batch_normalization_978
# False:	batch_normalization_979
# False:	activation_970
# False:	activation_973
# False:	activation_978
# False:	activation_979
# False:	mixed4
# False:	conv2d_984
# False:	batch_normalization_984
# False:	activation_984
# False:	conv2d_985
# False:	batch_normalization_985
# False:	activation_985
# False:	conv2d_981
# False:	conv2d_986
# False:	batch_normalization_981
# False:	batch_normalization_986
# False:	activation_981
# False:	activation_986
# False:	conv2d_982
# False:	conv2d_987
# False:	batch_normalization_982
# False:	batch_normalization_987
# False:	activation_982
# False:	activation_987
# False:	average_pooling2d_94
# False:	conv2d_980
# False:	conv2d_983
# False:	conv2d_988
# False:	conv2d_989
# False:	batch_normalization_980
# False:	batch_normalization_983
# False:	batch_normalization_988
# False:	batch_normalization_989
# False:	activation_980
# False:	activation_983
# False:	activation_988
# False:	activation_989
# False:	mixed5
# False:	conv2d_994
# False:	batch_normalization_994
# False:	activation_994
# False:	conv2d_995
# False:	batch_normalization_995
# False:	activation_995
# False:	conv2d_991
# False:	conv2d_996
# False:	batch_normalization_991
# False:	batch_normalization_996
# False:	activation_991
# False:	activation_996
# False:	conv2d_992
# False:	conv2d_997
# False:	batch_normalization_992
# False:	batch_normalization_997
# False:	activation_992
# False:	activation_997
# False:	average_pooling2d_95
# False:	conv2d_990
# False:	conv2d_993
# False:	conv2d_998
# False:	conv2d_999
# False:	batch_normalization_990
# False:	batch_normalization_993
# False:	batch_normalization_998
# False:	batch_normalization_999
# False:	activation_990
# False:	activation_993
# False:	activation_998
# False:	activation_999
# False:	mixed6
# False:	conv2d_1004
# False:	batch_normalization_1004
# False:	activation_1004
# False:	conv2d_1005
# False:	batch_normalization_1005
# False:	activation_1005
# False:	conv2d_1001
# False:	conv2d_1006
# False:	batch_normalization_1001
# False:	batch_normalization_1006
# False:	activation_1001
# False:	activation_1006
# False:	conv2d_1002
# False:	conv2d_1007
# False:	batch_normalization_1002
# False:	batch_normalization_1007
# False:	activation_1002
# False:	activation_1007
# False:	average_pooling2d_96
# False:	conv2d_1000
# False:	conv2d_1003
# False:	conv2d_1008
# False:	conv2d_1009
# False:	batch_normalization_1000
# False:	batch_normalization_1003
# False:	batch_normalization_1008
# False:	batch_normalization_1009
# False:	activation_1000
# False:	activation_1003
# False:	activation_1008
# False:	activation_1009
# False:	mixed7
# False:	conv2d_1012
# False:	batch_normalization_1012
# False:	activation_1012
# False:	conv2d_1013
# False:	batch_normalization_1013
# False:	activation_1013
# False:	conv2d_1010
# False:	conv2d_1014
# False:	batch_normalization_1010
# False:	batch_normalization_1014
# False:	activation_1010
# False:	activation_1014
# False:	conv2d_1011
# False:	conv2d_1015
# False:	batch_normalization_1011
# False:	batch_normalization_1015
# False:	activation_1011
# False:	activation_1015
# False:	max_pooling2d_43
# False:	mixed8
# False:	conv2d_1020
# False:	batch_normalization_1020
# False:	activation_1020
# False:	conv2d_1017
# False:	conv2d_1021
# False:	batch_normalization_1017
# False:	batch_normalization_1021
# False:	activation_1017
# False:	activation_1021
# False:	conv2d_1018
# False:	conv2d_1019
# False:	conv2d_1022
# True:	conv2d_1023
# True:	average_pooling2d_97
# True:	conv2d_1016
# True:	batch_normalization_1018
# True:	batch_normalization_1019
# True:	batch_normalization_1022
# True:	batch_normalization_1023
# True:	conv2d_1024
# True:	batch_normalization_1016
# True:	activation_1018
# True:	activation_1019
# True:	activation_1022
# True:	activation_1023
# True:	batch_normalization_1024
# True:	activation_1016
# True:	mixed9_0
# True:	concatenate_20
# True:	activation_1024
# True:	mixed9
# True:	conv2d_1029
# True:	batch_normalization_1029
# True:	activation_1029
# True:	conv2d_1026
# True:	conv2d_1030
# True:	batch_normalization_1026
# True:	batch_normalization_1030
# True:	activation_1026
# True:	activation_1030
# True:	conv2d_1027
# True:	conv2d_1028
# True:	conv2d_1031
# True:	conv2d_1032
# True:	average_pooling2d_98
# True:	conv2d_1025
# True:	batch_normalization_1027
# True:	batch_normalization_1028
# True:	batch_normalization_1031
# True:	batch_normalization_1032
# True:	conv2d_1033
# True:	batch_normalization_1025
# True:	activation_1027
# True:	activation_1028
# True:	activation_1031
# True:	activation_1032
# True:	batch_normalization_1033
# True:	activation_1025
# True:	mixed9_1
# True:	concatenate_21
# True:	activation_1033
# True:	mixed10

# %%
history = model.fit(
    x = X_train_dl_split,
    y = y_train_dl_split,
    epochs=50,
    validation_split= 0.2
)
# Out:
# Epoch 1/50
# 6/6 [==============================] - 1s 117ms/step - loss: 0.7107 - accuracy: 0.6205 - val_loss: 1.0907 - val_accuracy: 0.0189
# Epoch 2/50
# 6/6 [==============================] - 1s 111ms/step - loss: 0.6646 - accuracy: 0.6265 - val_loss: 0.7883 - val_accuracy: 0.3396
# Epoch 3/50
# 6/6 [==============================] - 1s 116ms/step - loss: 0.6704 - accuracy: 0.6024 - val_loss: 0.6297 - val_accuracy: 0.6604
# Epoch 4/50
# 6/6 [==============================] - 1s 111ms/step - loss: 0.6300 - accuracy: 0.6867 - val_loss: 0.6067 - val_accuracy: 0.7170
# Epoch 5/50
# 6/6 [==============================] - 1s 111ms/step - loss: 0.6244 - accuracy: 0.6446 - val_loss: 0.6152 - val_accuracy: 0.6981
# Epoch 6/50
# 6/6 [==============================] - 1s 114ms/step - loss: 0.6134 - accuracy: 0.6988 - val_loss: 0.6222 - val_accuracy: 0.6792
# Epoch 7/50
# 6/6 [==============================] - 1s 119ms/step - loss: 0.6197 - accuracy: 0.6867 - val_loss: 0.6711 - val_accuracy: 0.6226
# Epoch 8/50
# 6/6 [==============================] - 1s 126ms/step - loss: 0.5510 - accuracy: 0.7229 - val_loss: 0.6781 - val_accuracy: 0.6038
# Epoch 9/50
# 6/6 [==============================] - 1s 118ms/step - loss: 0.5691 - accuracy: 0.7169 - val_loss: 0.7091 - val_accuracy: 0.5472
# Epoch 10/50
# 6/6 [==============================] - 1s 127ms/step - loss: 0.5738 - accuracy: 0.7410 - val_loss: 0.7020 - val_accuracy: 0.5660
# Epoch 11/50
# 6/6 [==============================] - 1s 117ms/step - loss: 0.5475 - accuracy: 0.8193 - val_loss: 0.6033 - val_accuracy: 0.6792
# Epoch 12/50
# 6/6 [==============================] - 1s 115ms/step - loss: 0.5558 - accuracy: 0.7470 - val_loss: 0.5633 - val_accuracy: 0.7170
# Epoch 13/50
# 6/6 [==============================] - 1s 111ms/step - loss: 0.5490 - accuracy: 0.7169 - val_loss: 0.5440 - val_accuracy: 0.7547
# Epoch 14/50
# 6/6 [==============================] - 1s 111ms/step - loss: 0.5647 - accuracy: 0.7410 - val_loss: 0.5526 - val_accuracy: 0.7170
# Epoch 15/50
# 6/6 [==============================] - 1s 112ms/step - loss: 0.4977 - accuracy: 0.8253 - val_loss: 0.5906 - val_accuracy: 0.6792
# Epoch 16/50
# 6/6 [==============================] - 1s 114ms/step - loss: 0.4748 - accuracy: 0.8494 - val_loss: 0.5786 - val_accuracy: 0.7358
# Epoch 17/50
# 6/6 [==============================] - 1s 111ms/step - loss: 0.5207 - accuracy: 0.7711 - val_loss: 0.5477 - val_accuracy: 0.7358
# Epoch 18/50
# 6/6 [==============================] - 1s 112ms/step - loss: 0.5076 - accuracy: 0.7590 - val_loss: 0.5356 - val_accuracy: 0.7547
# Epoch 19/50
# 6/6 [==============================] - 1s 110ms/step - loss: 0.5038 - accuracy: 0.7892 - val_loss: 0.5380 - val_accuracy: 0.7358
# Epoch 20/50
# 6/6 [==============================] - 1s 112ms/step - loss: 0.4969 - accuracy: 0.8072 - val_loss: 0.5089 - val_accuracy: 0.7925
# Epoch 21/50
# 6/6 [==============================] - 1s 111ms/step - loss: 0.4447 - accuracy: 0.8494 - val_loss: 0.4669 - val_accuracy: 0.8113
# Epoch 22/50
# 6/6 [==============================] - 1s 111ms/step - loss: 0.3880 - accuracy: 0.8855 - val_loss: 0.4873 - val_accuracy: 0.7925
# Epoch 23/50
# 6/6 [==============================] - 1s 111ms/step - loss: 0.4309 - accuracy: 0.8554 - val_loss: 0.4879 - val_accuracy: 0.7925
# Epoch 24/50
# 6/6 [==============================] - 1s 114ms/step - loss: 0.4278 - accuracy: 0.7952 - val_loss: 0.4531 - val_accuracy: 0.8302
# Epoch 25/50
# 6/6 [==============================] - 1s 110ms/step - loss: 0.4138 - accuracy: 0.8434 - val_loss: 0.4456 - val_accuracy: 0.8302
# Epoch 26/50
# 6/6 [==============================] - 1s 112ms/step - loss: 0.4330 - accuracy: 0.8434 - val_loss: 0.4433 - val_accuracy: 0.8113
# Epoch 27/50
# 6/6 [==============================] - 1s 122ms/step - loss: 0.4422 - accuracy: 0.7892 - val_loss: 0.5193 - val_accuracy: 0.7547
# Epoch 28/50
# 6/6 [==============================] - 1s 126ms/step - loss: 0.4031 - accuracy: 0.8253 - val_loss: 0.4877 - val_accuracy: 0.7925
# Epoch 29/50
# 6/6 [==============================] - 1s 127ms/step - loss: 0.3651 - accuracy: 0.8976 - val_loss: 0.4390 - val_accuracy: 0.8302
# Epoch 30/50
# 6/6 [==============================] - 1s 125ms/step - loss: 0.4169 - accuracy: 0.8434 - val_loss: 0.3640 - val_accuracy: 0.9245
# Epoch 31/50
# 6/6 [==============================] - 1s 117ms/step - loss: 0.3521 - accuracy: 0.8855 - val_loss: 0.3420 - val_accuracy: 0.9434
# Epoch 32/50
# 6/6 [==============================] - 1s 114ms/step - loss: 0.3683 - accuracy: 0.8916 - val_loss: 0.3339 - val_accuracy: 0.9434
# Epoch 33/50
# 6/6 [==============================] - 1s 109ms/step - loss: 0.3798 - accuracy: 0.8554 - val_loss: 0.3113 - val_accuracy: 0.9434
# Epoch 34/50
# 6/6 [==============================] - 1s 115ms/step - loss: 0.3461 - accuracy: 0.8855 - val_loss: 0.2877 - val_accuracy: 0.9434
# Epoch 35/50
# 6/6 [==============================] - 1s 110ms/step - loss: 0.2862 - accuracy: 0.9217 - val_loss: 0.3081 - val_accuracy: 0.9434
# Epoch 36/50
# 6/6 [==============================] - 1s 111ms/step - loss: 0.3444 - accuracy: 0.8675 - val_loss: 0.3032 - val_accuracy: 0.9434
# Epoch 37/50
# 6/6 [==============================] - 1s 111ms/step - loss: 0.3352 - accuracy: 0.8916 - val_loss: 0.3438 - val_accuracy: 0.9057
# Epoch 38/50
# 6/6 [==============================] - 1s 109ms/step - loss: 0.3787 - accuracy: 0.8373 - val_loss: 0.3067 - val_accuracy: 0.9245
# Epoch 39/50
# 6/6 [==============================] - 1s 109ms/step - loss: 0.2925 - accuracy: 0.8976 - val_loss: 0.2763 - val_accuracy: 0.9434
# Epoch 40/50
# 6/6 [==============================] - 1s 112ms/step - loss: 0.2848 - accuracy: 0.9217 - val_loss: 0.2373 - val_accuracy: 0.9434
# Epoch 41/50
# 6/6 [==============================] - 1s 110ms/step - loss: 0.2619 - accuracy: 0.9157 - val_loss: 0.2517 - val_accuracy: 0.9434
# Epoch 42/50
# 6/6 [==============================] - 1s 114ms/step - loss: 0.2580 - accuracy: 0.9337 - val_loss: 0.2622 - val_accuracy: 0.9434
# Epoch 43/50
# 6/6 [==============================] - 1s 112ms/step - loss: 0.3083 - accuracy: 0.9036 - val_loss: 0.2708 - val_accuracy: 0.9434
# Epoch 44/50
# 6/6 [==============================] - 1s 114ms/step - loss: 0.3103 - accuracy: 0.9096 - val_loss: 0.2319 - val_accuracy: 0.9434
# Epoch 45/50
# 6/6 [==============================] - 1s 109ms/step - loss: 0.2941 - accuracy: 0.8916 - val_loss: 0.2340 - val_accuracy: 0.9434
# Epoch 46/50
# 6/6 [==============================] - 1s 110ms/step - loss: 0.2765 - accuracy: 0.9398 - val_loss: 0.2318 - val_accuracy: 0.9434
# Epoch 47/50
# 6/6 [==============================] - 1s 119ms/step - loss: 0.2955 - accuracy: 0.8795 - val_loss: 0.2432 - val_accuracy: 0.9434
# Epoch 48/50
# 6/6 [==============================] - 1s 123ms/step - loss: 0.2545 - accuracy: 0.8976 - val_loss: 0.2664 - val_accuracy: 0.9057
# Epoch 49/50
# 6/6 [==============================] - 1s 120ms/step - loss: 0.3233 - accuracy: 0.8855 - val_loss: 0.2818 - val_accuracy: 0.9057
# Epoch 50/50
# 6/6 [==============================] - 1s 124ms/step - loss: 0.2163 - accuracy: 0.9578 - val_loss: 0.2587 - val_accuracy: 0.9057

# %%
# Evaluate the model
scores = model.evaluate(X_test_dl_split, y_test_dl_split, verbose=1)
y_pred_dl = model.predict(X_test_dl_split)
# Out:
# 3/3 [==============================] - 0s 74ms/step - loss: 0.2233 - accuracy: 0.8933
# 3/3 [==============================] - 0s 65ms/step

# %%
y_pred_classes = np.argmax(y_pred_dl, axis=1)
y_true_classes = np.argmax(y_test_dl_split, axis=1)
conf_matrix = confusion_matrix(y_true_classes, y_pred_classes)
specificity = conf_matrix[0][0] / (conf_matrix[0][0] + conf_matrix[0][1])
recall = conf_matrix[1][1] / (conf_matrix[1][1] + conf_matrix[1][0])

# Plot training history
plt.figure(figsize=(12, 8))
# Plot Accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')  # Corrected ylabel to 'Accuracy'
plt.title('Accuracy vs. Epochs')
plt.legend()

# %%
# Plot AUC-ROC
plt.subplot(1, 2, 2)
fpr, tpr, _ = roc_curve(y_true_classes, y_pred_dl[:, 1])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr, label='AUC = {:.2f}'.format(roc_auc))
plt.plot([0, 1], [0, 1], linestyle='--', color='grey', label='Random')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('AUC-ROC Curve')
plt.legend()

plt.tight_layout()
plt.show()

# Print evaluation results
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
print('Sensitivity(recall):', recall)
print('Specificity:', specificity)
print('Precision:', precision_score(y_true_classes, y_pred_classes))
print('F1 Score:', f1_score(y_true_classes, y_pred_classes))
print('AUC-ROC Score:', roc_auc_score(y_true_classes, y_pred_dl[:, 1]))
print(conf_matrix)
model.summary()

from tensorflow.keras.utils import plot_model
# Explore model visually
plot_model(
    model, dpi=60,
    show_shapes=True
)
# Out:
# Test loss: 0.22332361340522766
# Test accuracy: 0.8933333158493042
# Sensitivity(recall): 0.8918918918918919
# Specificity: 0.9210526315789473
# Precision: 0.9166666666666666
# F1 Score: 0.9041095890410958
# AUC-ROC Score: 0.9765291607396871
# [[35  3]
#  [ 4 33]]
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_10 (Rescaling)    (None, 224, 224, 3)       0
#
#  inception_v3 (Functional)   (None, 5, 5, 2048)        21802784
#
#  flatten_10 (Flatten)        (None, 51200)             0
#
#  dense_37 (Dense)            (None, 1024)              52429824
#
#  dropout_17 (Dropout)        (None, 1024)              0
#
#  dense_38 (Dense)            (None, 2048)              2099200
#
#  dropout_18 (Dropout)        (None, 2048)              0
#
#  dense_39 (Dense)            (None, 4096)              8392704
#
#  dense_40 (Dense)            (None, 2)                 8194
#
# =================================================================
# Total params: 84732706 (323.23 MB)
# Trainable params: 62929922 (240.06 MB)
# Non-trainable params: 21802784 (83.17 MB)
# _________________________________________________________________
